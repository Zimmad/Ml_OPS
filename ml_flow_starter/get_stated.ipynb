# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000") #This uri can be your remote repository.

# %%
mlflow.set_experiment("Check the local host connection to see whether everything is working")
with mlflow.start_run():
    mlflow.log_metric("Tesing: loging some info", 1)
    mlflow.log_metric("secong information log", 2)
# Out:
# 🏃 View run brawny-cat-59 at: http://127.0.0.1:5000/#/experiments/1/runs/ade86207b1714d38a3c8355f3aaf53a2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
